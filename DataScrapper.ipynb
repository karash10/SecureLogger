# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from robotexclusionrulesparser import RobotExclusionRulesParser
import time

# --- Configuration ---
# The list of 10 traditional websites to crawl
TARGET_WEBSITES = [
    "https://www.thehindu.com/",
    "https://www.iisc.ac.in/",
    "https://www.isro.gov.in/",
    "https://archive.org/",
    "https://news.mit.edu/",
    "https://www.nasa.gov/",
    "https://www.theguardian.com/world",
    "https://www.gutenberg.org/",
    "https://www.nationalgeographic.com/",
    "https://eng.bangaloreuniversity.ac.in/","https://timesofindia.indiatimes.com/",
    "https://www.ncbs.res.in/",
    "https://www.nytimes.com/international/",
    "https://www.espncricinfo.com/",
    "https://www.reuters.com/",
    "https://www.taralaya.org/",
    "https://www.kyoto-u.ac.jp/en",
    "https://www.britishmuseum.org/",
    "https://www.livemint.com/",
    "https://www.who.int/"
]
OUTPUT_FILE = "combined_dataset.txt"
MAX_LINKS_PER_SITE = 40  # The limit for links from each website
USER_AGENT = "SecureLoggerBot/1.0"   # How your bot identifies itself

# --- Crawler Logic ---
all_collected_paths = set()

print(f"[*] Starting multi-site crawl...")

for base_url in TARGET_WEBSITES:
    print(f"\n--- Crawling {base_url} ---")
    
    try:
        # 1. Fetch and parse robots.txt for the current site
        parsed_base_url = urlparse(base_url)
        robots_url = f"{parsed_base_url.scheme}://{parsed_base_url.netloc}/robots.txt"
        rerp = RobotExclusionRulesParser()
        rerp.fetch(robots_url)
        print(f"[+] robots.txt for {base_url} loaded.")
        
        urls_to_visit = [base_url]
        visited_urls = set()
        links_found_for_site = 0
        
        # 2. Start crawling the site until the limit is reached
        while urls_to_visit and links_found_for_site < MAX_LINKS_PER_SITE:
            current_url = urls_to_visit.pop(0)
            
            if current_url in visited_urls:
                continue

            # Respect the rules from robots.txt
            if not rerp.is_allowed(USER_AGENT, current_url):
                print(f"  [-] Disallowed by robots.txt: {current_url}")
                continue

            visited_urls.add(current_url)
            
            try:
                # 3. Fetch the page
                headers = {'User-Agent': USER_AGENT}
                response = requests.get(current_url, headers=headers, timeout=5)
                
                if response.status_code == 200:
                    # 4. Save the allowed URL path
                    path = urlparse(current_url).path
                    if not path: path = '/'
                    
                    if path not in all_collected_paths:
                        all_collected_paths.add(path)
                        links_found_for_site += 1
                        print(f"  [{links_found_for_site}/{MAX_LINKS_PER_SITE}] Found: {path}")

                    # 5. Find all new links on the page
                    soup = BeautifulSoup(response.content, 'html.parser')
                    for link in soup.find_all('a', href=True):
                        absolute_url = urljoin(base_url, link['href'])
                        # Only follow links that are on the same website
                        if urlparse(absolute_url).netloc == parsed_base_url.netloc:
                            if absolute_url not in visited_urls:
                                urls_to_visit.append(absolute_url)
                                
            except requests.RequestException as e:
                print(f"[!] Error fetching {current_url}: {e}")
    
    except Exception as e:
        print(f"[!] Critical error processing {base_url}: {e}")

# --- Save the Final Dataset ---
print(f"\n[*] Crawl finished. Total unique paths found: {len(all_collected_paths)}")
with open(OUTPUT_FILE, 'w') as f:
    # Sort the list for a clean output file
    for path in sorted(list(all_collected_paths)):
        f.write(path + '\n')
print(f"[*] Dataset saved to {OUTPUT_FILE}")
# Out:
# [*] Starting multi-site crawl...
#
# --- Crawling https://www.thehindu.com/ ---
# [+] robots.txt for https://www.thehindu.com/ loaded.
#   [-] Disallowed by robots.txt: https://www.thehindu.com/
#
# --- Crawling https://www.iisc.ac.in/ ---
# [+] robots.txt for https://www.iisc.ac.in/ loaded.
#   [-] Disallowed by robots.txt: https://www.iisc.ac.in/
#
# --- Crawling https://www.isro.gov.in/ ---
# [+] robots.txt for https://www.isro.gov.in/ loaded.
#   [-] Disallowed by robots.txt: https://www.isro.gov.in/
#
# --- Crawling https://archive.org/ ---
# [+] robots.txt for https://archive.org/ loaded.
#   [1/40] Found: /
#
# --- Crawling https://news.mit.edu/ ---
# [+] robots.txt for https://news.mit.edu/ loaded.
#   [1/40] Found: /topics
#   [2/40] Found: /topic/machine-learning
#   [3/40] Found: /topic/sustainability
#   [4/40] Found: /topic/startups
#   [5/40] Found: /topic/black-holes
#   [6/40] Found: /topic/classes-and-programs
#   [7/40] Found: /departments
#   [8/40] Found: /department/aeronautics-and-astronautics
#   [9/40] Found: /department/brain-and-cognitive-sciences
#   [10/40] Found: /department/architecture
#   [11/40] Found: /department/political-science
#   [12/40] Found: /department/mechanical-engineering
#   [13/40] Found: /centers-labs-programs
#   [14/40] Found: /clp/abdul-latif-jameel-poverty-action-lab-j-pal
#   [15/40] Found: /clp/picower-institute
#   [16/40] Found: /clp/media-lab
#   [17/40] Found: /clp/lincoln-laboratory
#   [18/40] Found: /school/architecture-and-planning
#   [19/40] Found: /school/engineering
#   [20/40] Found: /school/humanities-arts-and-social-sciences
#   [21/40] Found: /school/management
#   [22/40] Found: /school/science
#   [23/40] Found: /school/mit-schwarzman-college-computing
#   [24/40] Found: /in-the-media
#   [25/40] Found: /podcasts
#   [26/40] Found: /2025/accounting-uncertainty-help-engineers-design-complex-systems-1002
#   [27/40] Found: /2025/palladium-filters-could-enable-cheaper-more-efficient-generation-hydrogen-fuel-1001
#   [28/40] Found: /2025/cysteine-rich-diet-may-promote-intestinal-lining-regeneration-study-suggests-1001
#   [29/40] Found: /2025/system-lets-people-personalize-online-social-spaces-while-staying-connected-1001
#   [30/40] Found: /2025/responding-to-generative-ai-climate-impact-0930
#   [31/40] Found: /news-clip/forbes-800
#   [32/40] Found: /news-clip/popular-science-290
#   [33/40] Found: /2025/mit-cognitive-scientists-reveal-why-some-sentences-stand-out-1001
#   [34/40] Found: /2025/concrete-battery-now-packs-ten-times-power-1001
#   [35/40] Found: /2025/mit-opencourseware-living-testament-nobility-open-unbounded-learning-1001
#   [36/40] Found: /2025/mit-joins-constructing-giant-magellan-telescope-0930
#   [37/40] Found: /2025/3-questions-new-mission-to-uranus-0930
#   [38/40] Found: /2025/first-animals-earth-may-have-been-sea-sponges-study-suggests-0929
#   [39/40] Found: /2025/how-federal-research-support-has-helped-create-life-changing-medicines-0925
#   [40/40] Found: /2025/study-finds-key-role-non-neural-brain-cells-processing-vision-0930
#
# --- Crawling https://www.nasa.gov/ ---
# [+] robots.txt for https://www.nasa.gov/ loaded.
#   [1/40] Found: /news/
#   [2/40] Found: /2025-news-releases/
#   [3/40] Found: /news/recently-published/
#   [4/40] Found: /podcasts-and-audio/
#   [5/40] Found: /nasa-blogs/
#   [6/40] Found: /newsletters/
#   [7/40] Found: /social-media/
#   [8/40] Found: /news/media-contacts/
#   [9/40] Found: /events
#   [24/40] Found: /tv/show/ca01e65b-8a36-4621-a87a-f9ab3dbc93ce
#   [25/40] Found: /tv/movies-and-specials/b4e0bf86-6bcf-4577-9450-fee3f75c5a13
#   [26/40] Found: /tv/show/ad9c7541-abcd-4c39-a4d0-04adcb836c27
#   [27/40] Found: /tv/movies-and-specials/9a774674-f226-4e6c-a477-2d54b249486d
#   [28/40] Found: /tv/show/0e054fb6-8330-4970-a03c-0c271ad5daf6
#   [29/40] Found: /tv/show/ea8e395b-67a7-4942-8f6f-a569bd179daf
#   [30/40] Found: /tv/show/696719d8-b522-404b-916b-1c624df63240
# [!] Error fetching https://www.nationalgeographic.com/tv/show/45ca4ccc-7936-4df5-bcf9-9b1021382300: HTTPSConnectionPool(host='natgeotv.com', port=443): Read timed out. (read timeout=5)
#   [31/40] Found: /tv/show/5c3a7137-acb9-4d92-86c9-619b4d97199e
#   [32/40] Found: /tv/shows/port-protection-alaska
#   [33/40] Found: /tv/movies-and-specials/aabca359-75b6-4566-98e7-8dea8d3e790a
#   [34/40] Found: /tv/show/2eed9176-d3d2-4fec-a394-c9f42710de53
#   [35/40] Found: /tv/show/e75f8140-e0ce-4b3b-a3ab-a73073dbc7df
#   [36/40] Found: /tv/show/8e7c141b-f419-4e2c-bb6d-5c55d97a456a
#   [37/40] Found: /tv/movies-and-specials/d15b530f-32bb-4519-914c-51282c301ca3
#   [38/40] Found: /tv/movies-and-specials/e7c3fdf3-a2bb-4da4-95d8-fb4e6d4823f0
#   [39/40] Found: /expeditions/trip-search/signature-land-see-whats-new/
#   [40/40] Found: /expeditions/trip-types/ocean/
#
# --- Crawling https://eng.bangaloreuniversity.ac.in/ ---
# [!] Critical error processing https://eng.bangaloreuniversity.ac.in/: <urlopen error 0>
#
# --- Crawling https://timesofindia.indiatimes.com/ ---
# [+] robots.txt for https://timesofindia.indiatimes.com/ loaded.
#   [1/40] Found: /us
#   [2/40] Found: /weather
#   [3/40] Found: /toi-plus
#   [4/40] Found: /videos
#   [5/40] Found: /city
#   [6/40] Found: /city/mumbai
#   [7/40] Found: /city/delhi
#   [8/40] Found: /city/bangalore
# [!] Error fetching https://timesofindia.indiatimes.com/city/hyderabad: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
#   [9/40] Found: /city/kolkata
#   [10/40] Found: /city/chennai
#   [11/40] Found: /city/agra
# [!] Error fetching https://timesofindia.indiatimes.com/city/agartala: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
#   [12/40] Found: /city/ahmedabad
#   [13/40] Found: /city/ajmer
# [!] Error fetching https://timesofindia.indiatimes.com/city/amaravati: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
#   [14/40] Found: /city/amritsar
#   [15/40] Found: /city/bareilly
#   [16/40] Found: /city/bhubaneswar
#   [17/40] Found: /city/bhopal
# [!] Error fetching https://timesofindia.indiatimes.com/city/chandigarh: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
# [!] Error fetching https://timesofindia.indiatimes.com/city/aurangabad: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
#   [18/40] Found: /city/coimbatore
# [!] Error fetching https://timesofindia.indiatimes.com/city/cuttack: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
#   [19/40] Found: /city/dehradun
#   [20/40] Found: /city/erode
# [!] Error fetching https://timesofindia.indiatimes.com/city/faridabad: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
#   [21/40] Found: /city/ghaziabad
#   [22/40] Found: /city/goa
#   [23/40] Found: /city/gurgaon
#   [24/40] Found: /city/guwahati
#   [25/40] Found: /city/hubli
#   [26/40] Found: /city/imphal
#   [27/40] Found: /city/indore
# [!] Error fetching https://timesofindia.indiatimes.com/city/itanagar: HTTPSConnectionPool(host='timesofindia.indiatimes.com', port=443): Read timed out. (read timeout=5)
#   
#   [13/40] Found: /en/about/safety
#   [14/40] Found: /en/about/ranking-en
#   [15/40] Found: /en/research
#   [16/40] Found: /en/research/fields
#   [17/40] Found: /en/research/research-policy
#   [18/40] Found: /en/research/collaboration
#   [19/40] Found: /en/research/support-scholarship
#   [20/40] Found: /en/research/visa-housing-daily-life
#   [21/40] Found: /en/research/about
#   [22/40] Found: /en/research/research-compliance-ethics
#   [23/40] Found: /en/education-campus
#   [24/40] Found: /en/education-campus/education-and-admissions
#   [25/40] Found: /en/education-campus/career-guidance-for-students
#   [26/40] Found: /en/education-campus/procedures
#   [27/40] Found: /en/education-campus/facilities
#   [28/40] Found: /en/education-campus/faq
#   [29/40] Found: /en/global
#   [30/40] Found: /en/global/international-strategy
#   [31/40] Found: /en/global/global-profile
#   [32/40] Found: /en/global/global-partners
#   [33/40] Found: /en/global/international-risk-and-crisis-management
#   [34/40] Found: /en/global/global-usr
#   [35/40] Found: /en/global/concierge
#   [36/40] Found: /en/current
#   [37/40] Found: /en/alumni
#   [38/40] Found: /en/event
#   [39/40] Found: /en/access
#   [40/40] Found: /en/contact
#
# --- Crawling https://www.britishmuseum.org/ ---
# [+] robots.txt for https://www.britishmuseum.org/ loaded.
#   [-] Disallowed by robots.txt: https://www.britishmuseum.org/search
#   [-] Disallowed by robots.txt: https://www.britishmuseum.org/search
#   [-] Disallowed by robots.txt: https://www.britishmuseum.org/search
#
# --- Crawling https://www.livemint.com/ ---
# [+] robots.txt for https://www.livemint.com/ loaded.
#   [1/40] Found: /market/market-stats
#   [2/40] Found: /latest-news
#   [3/40] Found: /market
#   [4/40] Found: /market/stock-market-news
#   [5/40] Found: /market/ipo
#   [6/40] Found: /market/mark-to-market
#   [7/40] Found: /market/bonds
#   [8/40] Found: /market/commodities
#   [9/40] Found: /market/cryptocurrency
#   [10/40] Found: /market/india-indices
#   [11/40] Found: /gold-prices
#   [12/40] Found: /silver-prices
#   [13/40] Found: /fuel-prices-petrol
#   [14/40] Found: /fuel-prices-diesel
#   [15/40] Found: /news
#   [16/40] Found: /news/india
#   [17/40] Found: /news/world
#   [18/40] Found: /wsj
#   [19/40] Found: /economist
#   [20/40] Found: /news/us-news
#   [21/40] Found: /news/trends
#   [22/40] Found: /premium
#   [23/40] Found: /barrons
#   [24/40] Found: /topic/mint-explainer
#   [25/40] Found: /topic/long-story
#   [26/40] Found: /topic/primer
#   [27/40] Found: /topic/mint-snapview
#   [28/40] Found: /companies
#   [29/40] Found: /companies/start-ups
#   [30/40] Found: /companies/company-results
#   [31/40] Found: /companies/people
#   [32/40] Found: /money
#   [33/40] Found: /money/personal-finance
#   [34/40] Found: /insurance/news
#   [35/40] Found: /money/ask-mint-money
#   [36/40] Found: /mutual-fund
#   [37/40] Found: /mymint
#   [38/40] Found: /news/us-news/us-government-shutdown-live-updates-services-affected-complete-advisory-white-house-donald-trump-latest-news-1-october-11759309088104.html
#   [39/40] Found: /technology/gadgets
#   [40/40] Found: /technology/tech-reviews
#
# --- Crawling https://www.who.int/ ---
# [+] robots.txt for https://www.who.int/ loaded.
#   [-] Disallowed by robots.txt: https://www.who.int/
#
# [*] Crawl finished. Total unique paths found: 401
# [*] Dataset saved to combined_dataset.txt
